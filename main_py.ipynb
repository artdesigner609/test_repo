# %% [markdown]
# <a href="https://colab.research.google.com/github/artdesigner609/test_repo/blob/main/main_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
a = 10
b = 23
c = 45

z = (a^b) * c

print(z)
# Out:
# 1305

# %%
# let's see how AI generate code

# write a function to find sqrt of 456

# %%
import math

def find_sqrt(number):
    """Calculates the square root of a given number."""
    return math.sqrt(number)

# Calculate the square root of 456
number_to_find_sqrt = 526
result = find_sqrt(number_to_find_sqrt)
print(f"The square root of {number_to_find_sqrt} is {result}")
# Out:
# The square root of 526 is 22.93468988235943
